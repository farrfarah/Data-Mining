# %% [markdown]
# Nama : Farah Faizah\
# NIM : 121450002 \
# Kelas : RC

# %%
import pandas as pd #pandas untuk mengimport data

df1 = pd.read_csv("/content/diabetes_RS1.csv") #membaca file csv
df2 = pd.read_csv("/content/diabetes_RS2.csv")

# %%
df1.shape #meampilkan size data1
# Out:
# (768, 9)

# %%
df2.shape #menampilkan size data2
# Out:
# (1009, 14)

# %%
df1.head(5) #menampilkan 5 baris  teratas pada data 1
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df2.head(5) #menampilkan 5 baris  teratas pada data 2
# Out:
#     ID  No_Pation Gender   AGE  Urea    Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0  502      17975      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4   0.5
# 1  735      34221      M  26.0   4.5  62.0    4.9   3.7  1.4  1.1  2.1   0.6
# 2  420      47975      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4   0.5
# 3  680      87656      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4   0.5
# 4  504      34223      M  33.0   7.1  46.0    4.9   4.9  1.0  0.8  2.0   0.4
#
#     BMI CLASS
# 0  24.0     N
# 1  23.0     N
# 2  24.0     N
# 3  24.0     N
# 4  21.0     N

# %%
df1.tail(5) #menampilkan 5 baris terbawah pada data 1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df2.tail(5) #menampilkan 5 baris terbawah pada data 2
# Out:
#        ID  No_Pation Gender   AGE  Urea    Cr  HbA1c  Chol   TG  HDL  LDL  \
# 1004  191     454316      M  55.0   NaN  62.0    6.8   5.3  2.0  1.0  3.5
# 1005  192     454316      M  55.0   4.8  88.0    NaN   5.7  4.0  0.9  3.3
# 1006  193     454316      M  62.0   6.3  82.0    6.7   5.3  2.0  1.0  3.5
# 1007  194     454316      F  57.0   4.1  70.0    9.3   5.3  3.3  1.0  1.4
# 1008  195       4543      f  55.0   4.1  34.0   13.9   5.4  1.6  1.6  3.1
#
#       VLDL   BMI CLASS
# 1004   0.9  30.1    Y
# 1005   1.8  30.0    Y
# 1006   NaN  30.1    Y
# 1007   1.3  29.0    Y
# 1008   0.7  33.0    Y

# %%
df1.sample(5) #menampilkan 5 baris secara acak pada data 1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 94             2      142             82             18       64  24.7
# 354            3       90             78              0        0  42.7
# 389            3      100             68             23       81  31.6
# 514            3       99             54             19       86  25.6
# 75             1        0             48             20        0  24.7
#
#      DiabetesPedigreeFunction  Age  Outcome
# 94                      0.761   21        0
# 354                     0.559   21        0
# 389                     0.949   28        0
# 514                     0.154   24        0
# 75                      0.140   22        0

# %%
df2.sample(5) #menampilkan 5 baris secara acak pada data 2
# Out:
#       ID  No_Pation Gender   AGE  Urea    Cr  HbA1c  Chol   TG  HDL  LDL  \
# 23   390      34282      M  50.0   4.0  28.0    5.3   4.8  1.0  0.9  3.6
# 778  166      34537      M  53.0   5.9  67.0    9.9   5.2  1.8  0.9  3.6
# 419  449      24121      M  55.0   3.2  56.0    8.0   4.0  2.6  1.2  1.7
# 781  548      14389      F  60.0   4.1  56.0   13.1   4.4  2.0  1.0  2.5
# 442  771      34371      F  59.0   3.5  48.0    8.0   6.3  2.7  0.9  1.6
#
#      VLDL   BMI CLASS
# 23    0.4  23.0     N
# 778   0.6  33.0     Y
# 419   1.7  30.0     Y
# 781   0.9  29.0     Y
# 442   0.3  35.0     Y

# %%
df1.dtypes #menampilkan tipe atribut pada data 1
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
df2.dtypes #menampilkan tipe atribut pada data 2
# Out:
# ID             int64
# No_Pation      int64
# Gender        object
# AGE          float64
# Urea         float64
# Cr           float64
# HbA1c        float64
# Chol         float64
# TG           float64
# HDL          float64
# LDL          float64
# VLDL         float64
# BMI          float64
# CLASS         object
# dtype: object

# %%
df1.describe() #menampilkan deskripsi data berupa nilai perhitungan pada data 1
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df2.describe() #menampilkan deskripsi data berupa nilai perhitungan pada data 2
# Out:
#                 ID     No_Pation          AGE         Urea           Cr  \
# count  1009.000000  1.009000e+03  1008.000000  1008.000000  1007.000000
# mean    339.161546  2.717448e+05    53.620040     5.131094    68.973188
# std     239.738169  3.365681e+06     8.740975     2.931136    59.813297
# min       1.000000  1.230000e+02    25.000000     0.500000     6.000000
# 25%     127.000000  2.406500e+04    51.000000     3.700000    48.000000
# 50%     296.000000  3.439900e+04    55.000000     4.600000    60.000000
# 75%     548.000000  4.539000e+04    59.000000     5.700000    73.000000
# max     800.000000  7.543566e+07    79.000000    38.900000   800.000000
#
#              HbA1c         Chol           TG          HDL          LDL  \
# count  1006.000000  1007.000000  1007.000000  1008.000000  1007.000000
# mean      8.284155     4.863873     2.348769     1.204216     2.610119
# std       2.533576     1.297326     1.397487     0.658158     1.116095
# ...

# %% [markdown]
# ## Perbedaan karakteristik pada data 1 dan data 2
#
# data 1 \
#
# data 2 \

# %% [markdown]
# ##**Verifikasi data**

# %% [markdown]
# ##Identifikasi data yang hilang

# %%
df1.isnull().sum() #mengecek jumlah data yang hilang pada data 1
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df2.isnull().sum() #mengecek jumlah data yang hilang pada data 2
# Out:
# ID           0
# No_Pation    0
# Gender       0
# AGE          1
# Urea         1
# Cr           2
# HbA1c        3
# Chol         2
# TG           2
# HDL          1
# LDL          2
# VLDL         1
# BMI          0
# CLASS        0
# dtype: int64

# %% [markdown]
# ##Identifikasi pencilan data

# %%
korelasi1 = df1.corr()
korelasi1
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
import seaborn as sns
sns.heatmap(korelasi1)
# Out:
# <Axes: >

# %%
sns.boxplot (x = 'Pregnancies', data = df1)
# Out:
# <Axes: xlabel='Pregnancies'>

# %%
korelasi2 = df2.corr()
korelasi2
# Out:
# <ipython-input-18-002b33f4d238>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   korelasi2 = df2.corr()
#                  ID  No_Pation       AGE      Urea        Cr     HbA1c  \
# ID         1.000000   0.064584 -0.072858 -0.095439 -0.102539 -0.008293
# No_Pation  0.064584   1.000000 -0.088153 -0.018946  0.000853 -0.032219
# AGE       -0.072858  -0.088153  1.000000  0.110137  0.057138  0.381044
# Urea      -0.095439  -0.018946  0.110137  1.000000  0.624538 -0.024170
# Cr        -0.102539   0.000853  0.057138  0.624538  1.000000 -0.038256
# HbA1c     -0.008293  -0.032219  0.381044 -0.024170 -0.038256  1.000000
# Chol       0.043999  -0.030054  0.036421  0.000775 -0.007121  0.178141
# TG        -0.055433  -0.039816  0.145743  0.039616  0.056757  0.215808
# ...

# %%
import seaborn as sns
sns.heatmap(korelasi2)
# Out:
# <Axes: >

# %%
sns.boxplot(x='AGE',data= df2)
# Out:
# <Axes: xlabel='AGE'>
